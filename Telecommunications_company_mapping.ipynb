# %%
import pandas as pd

# Define the header and data
header = [
    "Common Script Name", "Fyers Script Name", "Angel One Script Name", "ICICI Script Name",
    "Kotak Script Name", "Zerodha Script Name", "Script Symbol", "Instrument Type",
    "Exchange", "Fyers ISIN", "Angel ISIN", "ICICI ISIN", "Kotak ISIN", "Zerodha ISIN",
    "Fyers BSE Code", "Angel BSE Code", "ICICI BSE Code", "52-Week High", "52-Week Low",
    "Avg Daily Volume", "Fyers Last Traded Price", "Angel Last Traded Price", "Fyers P/E Ratio",
    "Angel P/E Ratio", "Market Sector", "Currency", "Country", "Listing Date", "Dividend Yield",
    "Beta", "Annualized Volatility"
]

data = [
    ["Reliance Jio", "RJIO", "RELIANCE", "RIL", "RJIL", "RJIO", "RJIO", "Equity", "NSE",
     "INE251Y01014", "INE213H01023", "INE002A01018", "INE009A01026", "INE910S01026",
     "540006", "540049", "532715", "2500", "1800", "10000000", "2450", "2445", "35.2", "35.0",
     "Telecommunications", "INR", "India", "2016-09-05", "1.5", "0.8", "20"],
    
    ["Bharti Airtel", "AIRTEL", "BHARTI", "BHL", "BART", "AIRTEL", "BHARTI", "Equity", "NSE",
     "INE397D01024", "INE397D01024", "INE397D01024", "INE397D01024", "INE397D01024",
     "532454", "532454", "532454", "700", "520", "8000000", "695", "690", "28.1", "27.9",
     "Telecommunications", "INR", "India", "2002-11-06", "0.3", "0.9", "25"],
    
    ["Vodafone Idea", "VODAFONE", "VIDEOCON", "VIL", "IDEA", "IDEA", "IDEA", "Equity", "NSE",
     "INE963B01012", "INE963B01012", "INE963B01012", "INE963B01012", "INE963B01012",
     "532822", "532822", "532822", "15", "10", "5000000", "12.5", "12.4", "45.3", "45.0",
     "Telecommunications", "INR", "India", "2018-08-31", "0.0", "1.2", "30"],
    
    ["BSNL", "BSNL", "BSNL", "BSNL", "BSNL", "BSNL", "BSNL", "Equity", "NSE",
     "INE123B01010", "INE123B01010", "INE123B01010", "INE123B01010", "INE123B01010",
     "532792", "532792", "532792", "50", "35", "1500000", "45", "44", "10.5", "10.0",
     "Telecommunications", "INR", "India", "2000-05-01", "2.0", "0.5", "12"],
    
    ["MTNL", "MTNL", "MTNL", "MTNL", "MTNL", "MTNL", "MTNL", "Equity", "NSE",
     "INE129A01014", "INE129A01014", "INE129A01014", "INE129A01014", "INE129A01014",
     "532900", "532900", "532900", "25", "18", "1200000", "20", "19", "7.5", "7.2",
     "Telecommunications", "INR", "India", "2000-07-01", "0.5", "0.6", "9"]
]

# Create a DataFrame
df = pd.DataFrame(data, columns=header)

# Save the DataFrame to an Excel file
df.to_excel('Telecommunication_companies_mapping.xlsx', index=False)

# %%
import pandas as pd

# Data for Telecommunications
header = [
    "Common Script Name", "Fyers Script Name", "Angel One Script Name", "ICICI Script Name",
    "Kotak Script Name", "Zerodha Script Name", "Script Symbol", "Instrument Type",
    "Exchange", "Fyers ISIN", "Angel ISIN", "ICICI ISIN", "Kotak ISIN", "Zerodha ISIN",
    "Fyers BSE Code", "Angel BSE Code", "ICICI BSE Code", "52-Week High", "52-Week Low",
    "Avg Daily Volume", "Fyers Last Traded Price", "Angel Last Traded Price", "Fyers P/E Ratio",
    "Angel P/E Ratio", "Market Sector", "Currency", "Country", "Listing Date", "Dividend Yield",
    "Beta", "Annualized Volatility"
]

# Sample filled data for the telecommunications companies
data = [
    ["Reliance Jio", "RJIO", "RELIANCE", "RIL", "RJIL", "RJIO", "RJIO", "Equity", "NSE",
     "INE251Y01014", "INE213H01023", "INE002A01018", "INE009A01026", "INE910S01026",
     "540006", "540049", "532715", "2500", "1800", "10000000", "2450", "2445", "35.2", "35.0",
     "Telecommunications", "INR", "India", "2016-09-05", "1.5", "0.8", "20"],
    
    ["Bharti Airtel", "AIRTEL", "BHARTI", "BHL", "BART", "AIRTEL", "BHARTI", "Equity", "NSE",
     "INE397D01024", "INE397D01024", "INE397D01024", "INE397D01024", "INE397D01024",
     "532454", "532454", "532454", "700", "520", "8000000", "695", "690", "28.1", "27.9",
     "Telecommunications", "INR", "India", "2002-11-06", "0.3", "0.9", "25"],
    
    ["Vodafone Idea", "VODAFONE", "VIDEOCON", "VIL", "IDEA", "IDEA", "IDEA", "Equity", "NSE",
     "INE963B01012", "INE963B01012", "INE963B01012", "INE963B01012", "INE963B01012",
     "532822", "532822", "532822", "15", "10", "5000000", "12.5", "12.4", "45.3", "45.0",
     "Telecommunications", "INR", "India", "2018-08-31", "0.0", "1.2", "30"],
    
    ["BSNL", "BSNL", "BSNL", "BSNL", "BSNL", "BSNL", "BSNL", "Equity", "NSE",
     "INE123B01010", "INE123B01010", "INE123B01010", "INE123B01010", "INE123B01010",
     "532792", "532792", "532792", "50", "35", "1500000", "45", "44", "10.5", "10.0",
     "Telecommunications", "INR", "India", "2000-05-01", "2.0", "0.5", "12"],
    
    ["MTNL", "MTNL", "MTNL", "MTNL", "MTNL", "MTNL", "MTNL", "Equity", "NSE",
     "INE129A01014", "INE129A01014", "INE129A01014", "INE129A01014", "INE129A01014",
     "532900", "532900", "532900", "25", "18", "1200000", "20", "19", "7.5", "7.2",
     "Telecommunications", "INR", "India", "2000-07-01", "0.5", "0.6", "9"]
]

# Create a DataFrame
df = pd.DataFrame(data, columns=header)

# Print column names to verify
print("DataFrame Columns:", df.columns.tolist())

# Specify the individual broker filenames
brokers = {
    "Fyers": df[["Common Script Name", "Fyers Script Name", "Fyers ISIN", "Fyers BSE Code", 
                  "Fyers Last Traded Price", "Fyers P/E Ratio"]],
    "Angel One": df[["Common Script Name", "Angel One Script Name", "Angel ISIN", "Angel BSE Code", 
                      "Angel Last Traded Price", "Angel P/E Ratio"]],
    "ICICI": df[["Common Script Name", "ICICI Script Name", "ICICI ISIN", "ICICI BSE Code", 
                  "Fyers Last Traded Price", "Fyers P/E Ratio"]],
    "Kotak": df[["Common Script Name", "Kotak Script Name", "Kotak ISIN", "Kotak BSE Code", 
                  "Fyers Last Traded Price", "Fyers P/E Ratio"]],
    "Zerodha": df[["Common Script Name", "Zerodha Script Name", "Zerodha ISIN", "Zerodha BSE Code", 
                    "Fyers Last Traded Price", "Fyers P/E Ratio"]]
}

# Write each broker's data to a separate Excel file
for broker_name, broker_data in brokers.items():
    broker_data.to_excel(f"{broker_name}_telecommunications_data.xlsx", index=False)

print("Individual Excel files for each broker created successfully!")
# Out:
# DataFrame Columns: ['Common Script Name', 'Fyers Script Name', 'Angel One Script Name', 'ICICI Script Name', 'Kotak Script Name', 'Zerodha Script Name', 'Script Symbol', 'Instrument Type', 'Exchange', 'Fyers ISIN', 'Angel ISIN', 'ICICI ISIN', 'Kotak ISIN', 'Zerodha ISIN', 'Fyers BSE Code', 'Angel BSE Code', 'ICICI BSE Code', '52-Week High', '52-Week Low', 'Avg Daily Volume', 'Fyers Last Traded Price', 'Angel Last Traded Price', 'Fyers P/E Ratio', 'Angel P/E Ratio', 'Market Sector', 'Currency', 'Country', 'Listing Date', 'Dividend Yield', 'Beta', 'Annualized Volatility']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 56
#      46 print("DataFrame Columns:", df.columns.tolist())
#      48 # Specify the individual broker filenames
#      49 brokers = {
#      50     "Fyers": df[["Common Script Name", "Fyers Script Name", "Fyers ISIN", "Fyers BSE Code",
# ...
