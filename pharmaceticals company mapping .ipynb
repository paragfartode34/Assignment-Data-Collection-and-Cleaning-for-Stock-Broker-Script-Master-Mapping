# %%
import pandas as pd

# Data for pharmaceutical companies
data = {
    "Common Script Name": [
        "Sun Pharmaceutical", "Dr. Reddy's Laboratories", "Cipla",
        "Lupin Pharmaceuticals", "Aurobindo Pharma", "Cadila Healthcare",
        "Biocon", "Glenmark Pharmaceuticals", "Torrent Pharmaceuticals", "Wockhardt"
    ],
    "Fyers Script Name": [
        "SUNPHARMA", "DRREDDY", "CIPLA",
        "LUPIN", "AUROPHARMA", "CADILAHC",
        "BIOCON", "GLENMARK", "TORRENT", "WOCKHARDT"
    ],
    "Angel One Script Name": [
        "SUNPHARMA", "DRREDDY", "CIPLA",
        "LUPIN", "AUROPHARMA", "CADILAHC",
        "BIOCON", "GLENMARK", "TORRENT", "WOCKHARDT"
    ],
    "ICICI Script Name": [
        "SUNPHARMA", "DRREDDY", "CIPLA",
        "LUPIN", "AUROPHARMA", "CADILAHC",
        "BIOCON", "GLENMARK", "TORRENT", "WOCKHARDT"
    ],
    "Kotak Script Name": [
        "SUNPHARMA", "DRREDDY", "CIPLA",
        "LUPIN", "AUROPHARMA", "CADILAHC",
        "BIOCON", "GLENMARK", "TORRENT", "WOCKHARDT"
    ],
    "Zerodha Script Name": [
        "SUNPHARMA", "DRREDDY", "CIPLA",
        "LUPIN", "AUROPHARMA", "CADILAHC",
        "BIOCON", "GLENMARK", "TORRENT", "WOCKHARDT"
    ],
    "Script Symbol": [
        "SUNPHARMA", "DRREDDY", "CIPLA",
        "LUPIN", "AUROPHARMA", "CADILAHC",
        "BIOCON", "GLENMARK", "TORRENT", "WOCKHARDT"
    ],
    "Instrument Type": ["Equity"] * 10,
    "Exchange": ["NSE"] * 10,
    "Fyers ISIN": [
        "INE044A01036", "INE089A01023", "INE059A01026",
        "INE326A01037", "INE406A01037", "INE010B01027",
        "INE376G01013", "INE935A01025", "INE685A01027", "INE414A01024"
    ],
    "Angel ISIN": [
        "INE044A01036", "INE089A01023", "INE059A01026",
        "INE326A01037", "INE406A01037", "INE010B01027",
        "INE376G01013", "INE935A01025", "INE685A01027", "INE414A01024"
    ],
    "ICICI ISIN": [
        "INE044A01036", "INE089A01023", "INE059A01026",
        "INE326A01037", "INE406A01037", "INE010B01027",
        "INE376G01013", "INE935A01025", "INE685A01027", "INE414A01024"
    ],
    "Kotak ISIN": [
        "INE044A01036", "INE089A01023", "INE059A01026",
        "INE326A01037", "INE406A01037", "INE010B01027",
        "INE376G01013", "INE935A01025", "INE685A01027", "INE414A01024"
    ],
    "Zerodha ISIN": [
        "INE044A01036", "INE089A01023", "INE059A01026",
        "INE326A01037", "INE406A01037", "INE010B01027",
        "INE376G01013", "INE935A01025", "INE685A01027", "INE414A01024"
    ],
    "Fyers BSE Code": [
        "524715", "500124", "500087", 
        "500257", "524804", "532321", 
        "532523", "532296", "500420", "532300"
    ],
    "Angel BSE Code": [
        "524715", "500124", "500087", 
        "500257", "524804", "532321", 
        "532523", "532296", "500420", "532300"
    ],
    "ICICI BSE Code": [
        "524715", "500124", "500087", 
        "500257", "524804", "532321", 
        "532523", "532296", "500420", "532300"
    ],
    "52-Week High": [
        1200, 5000, 1000, 
        1200, 800, 650, 
        400, 1200, 2200, 900
    ],
    "52-Week Low": [
        600, 4000, 700, 
        900, 600, 450, 
        300, 850, 1600, 700
    ],
    "Avg Daily Volume": [
        1500000, 800000, 1200000, 
        1000000, 1500000, 1000000, 
        900000, 800000, 600000, 500000
    ],
    "Fyers Last Traded Price": [
        900, 4800, 950, 
        1050, 700, 600, 
        370, 950, 1900, 800
    ],
    "Angel Last Traded Price": [
        905, 4805, 955, 
        1045, 705, 605, 
        375, 955, 1895, 805
    ],
    "Fyers P/E Ratio": [
        25.5, 28.5, 20.0, 
        22.0, 18.5, 15.5, 
        24.0, 21.0, 26.5, 19.0
    ],
    "Angel P/E Ratio": [
        26.0, 29.0, 21.0, 
        23.0, 19.0, 16.0, 
        25.0, 22.0, 27.0, 20.0
    ],
    "Market Sector": ["Pharmaceuticals"] * 10,
    "Currency": ["INR"] * 10,
    "Country": ["India"] * 10,
    "Listing Date": [
        "1993-04-23", "1994-01-01", "1985-12-24",
        "1994-01-05", "2002-06-20", "1995-02-28",
        "2004-06-25", "2001-10-02", "2006-05-23", "1993-03-24"
    ],
    "Dividend Yield": [
        0.50, 1.00, 0.75, 
        1.20, 0.80, 0.90, 
        0.65, 0.50, 0.55, 0.75
    ],
    "Beta": [
        0.95, 1.10, 0.85, 
        0.90, 1.00, 1.05, 
        0.80, 0.70, 0.88, 0.75
    ],
    "Annualized Volatility": [
        "20%", "15%", "18%", 
        "16%", "12%", "14%", 
        "11%", "13%", "15%", "10%"
    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Save the DataFrame to an Excel file
df.to_excel('pharmacetical_companies_data.xlsx', index=False)

# %%
import pandas as pd

# Data for pharmaceutical companies
data = {
    "Common Script Name": [
        "Sun Pharmaceutical", "Dr. Reddy's Laboratories", "Cipla",
        "Lupin Pharmaceuticals", "Aurobindo Pharma", "Cadila Healthcare",
        "Biocon", "Glenmark Pharmaceuticals", "Torrent Pharmaceuticals", "Wockhardt"
    ],
    "Fyers Script Name": [
        "SUNPHARMA", "DRREDDY", "CIPLA",
        "LUPIN", "AUROPHARMA", "CADILAHC",
        "BIOCON", "GLENMARK", "TORRENT", "WOCKHARDT"
    ],
    "Angel One Script Name": [
        "SUNPHARMA", "DRREDDY", "CIPLA",
        "LUPIN", "AUROPHARMA", "CADILAHC",
        "BIOCON", "GLENMARK", "TORRENT", "WOCKHARDT"
    ],
    "ICICI Script Name": [
        "SUNPHARMA", "DRREDDY", "CIPLA",
        "LUPIN", "AUROPHARMA", "CADILAHC",
        "BIOCON", "GLENMARK", "TORRENT", "WOCKHARDT"
    ],
    "Kotak Script Name": [
        "SUNPHARMA", "DRREDDY", "CIPLA",
        "LUPIN", "AUROPHARMA", "CADILAHC",
        "BIOCON", "GLENMARK", "TORRENT", "WOCKHARDT"
    ],
    "Zerodha Script Name": [
        "SUNPHARMA", "DRREDDY", "CIPLA",
        "LUPIN", "AUROPHARMA", "CADILAHC",
        "BIOCON", "GLENMARK", "TORRENT", "WOCKHARDT"
    ],
    "Script Symbol": [
        "SUNPHARMA", "DRREDDY", "CIPLA",
        "LUPIN", "AUROPHARMA", "CADILAHC",
        "BIOCON", "GLENMARK", "TORRENT", "WOCKHARDT"
    ],
    "Instrument Type": ["Equity"] * 10,
    "Exchange": ["NSE"] * 10,
    "Fyers ISIN": [
        "INE044A01036", "INE089A01023", "INE059A01026",
        "INE326A01037", "INE406A01037", "INE010B01027",
        "INE376G01013", "INE935A01025", "INE685A01027", "INE414A01024"
    ],
    "Angel ISIN": [
        "INE044A01036", "INE089A01023", "INE059A01026",
        "INE326A01037", "INE406A01037", "INE010B01027",
        "INE376G01013", "INE935A01025", "INE685A01027", "INE414A01024"
    ],
    "ICICI ISIN": [
        "INE044A01036", "INE089A01023", "INE059A01026",
        "INE326A01037", "INE406A01037", "INE010B01027",
        "INE376G01013", "INE935A01025", "INE685A01027", "INE414A01024"
    ],
    "Kotak ISIN": [
        "INE044A01036", "INE089A01023", "INE059A01026",
        "INE326A01037", "INE406A01037", "INE010B01027",
        "INE376G01013", "INE935A01025", "INE685A01027", "INE414A01024"
    ],
    "Zerodha ISIN": [
        "INE044A01036", "INE089A01023", "INE059A01026",
        "INE326A01037", "INE406A01037", "INE010B01027",
        "INE376G01013", "INE935A01025", "INE685A01027", "INE414A01024"
    ],
    "Fyers BSE Code": [
        "524715", "500124", "500087", 
        "500257", "524804", "532321", 
        "532523", "532296", "500420", "532300"
    ],
    "Angel BSE Code": [
        "524715", "500124", "500087", 
        "500257", "524804", "532321", 
        "532523", "532296", "500420", "532300"
    ],
    "ICICI BSE Code": [
        "524715", "500124", "500087", 
        "500257", "524804", "532321", 
        "532523", "532296", "500420", "532300"
    ],
    "Kotak BSE Code": [  # Make sure this column is defined in the original data.
        "524715", "500124", "500087", 
        "500257", "524804", "532321", 
        "532523", "532296", "500420", "532300"
    ],
    "Zerodha BSE Code": [  # Add Zerodha BSE Code if required.
        "524715", "500124", "500087", 
        "500257", "524804", "532321", 
        "532523", "532296", "500420", "532300"
    ],
    "52-Week High": [
        1200, 5000, 1000, 
        1200, 800, 650, 
        400, 1200, 2200, 900
    ],
    "52-Week Low": [
        600, 4000, 700, 
        900, 600, 450, 
        300, 850, 1600, 700
    ],
    "Avg Daily Volume": [
        1500000, 800000, 1200000, 
        1000000, 1500000, 1000000, 
        900000, 800000, 600000, 500000
    ],
    "Fyers Last Traded Price": [
        900, 4800, 950, 
        1050, 700, 600, 
        370, 950, 1900, 800
    ],
    "Angel Last Traded Price": [
        905, 4805, 955, 
        1045, 705, 605, 
        375, 955, 1895, 805
    ],
    "Fyers P/E Ratio": [
        25.5, 28.5, 20.0, 
        22.0, 18.5, 15.5, 
        24.0, 21.0, 26.5, 19.0
    ],
    "Angel P/E Ratio": [
        26.0, 29.0, 21.0, 
        23.0, 19.0, 16.0, 
        25.0, 22.0, 27.0, 20.0
    ],
    "Market Sector": ["Pharmaceuticals"] * 10,
    "Currency": ["INR"] * 10,
    "Country": ["India"] * 10,
    "Listing Date": [
        "1993-04-23", "1994-01-01", "1985-12-24",
        "1994-01-05", "2002-06-20", "1995-02-28",
        "2004-06-25", "2001-10-02", "2006-05-23", "1993-03-24"
    ],
    "Dividend Yield": [
        0.50, 1.00, 0.75, 
        1.20, 0.80, 0.90, 
        0.65, 0.50, 0.55, 0.75
    ],
    "Beta": [
        0.95, 1.10, 0.85, 
        0.90, 1.00, 1.05, 
        0.80, 0.70, 0.88, 0.75
    ],
    "Annualized Volatility": [
        "20%", "15%", "18%", 
        "16%", "12%", "14%", 
        "11%", "13%", "15%", "10%"
    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Print out the available columns
print("Available columns in the DataFrame:")
print(df.columns.tolist())

# Define the brokers and their corresponding columns
brokers = {
    "Fyers": [
        "Common Script Name", "Fyers Script Name", "Fyers ISIN",
        "Fyers BSE Code", "52-Week High", "52-Week Low",
        "Avg Daily Volume", "Fyers Last Traded Price",
        "Fyers P/E Ratio", "Market Sector", "Currency", "Country", "Listing Date",
        "Dividend Yield", "Beta", "Annualized Volatility"
    ],
    "Angel": [
        "Common Script Name", "Angel Script Name", "Angel ISIN",
        "Angel BSE Code", "52-Week High", "52-Week Low",
        "Avg Daily Volume", "Fyers Last Traded Price", 
        "Fyers P/E Ratio", "Market Sector", "Currency", "Country", "Listing Date",
        "Dividend Yield", "Beta", "Annualized Volatility"
    ],
    "ICICI": [
        "Common Script Name", "ICICI Script Name", "ICICI ISIN",
        "ICICI BSE Code", "52-Week High", "52-Week Low",
        "Avg Daily Volume", "Fyers Last Traded Price", 
        "Fyers P/E Ratio", "Market Sector", "Currency", "Country", "Listing Date",
        "Dividend Yield", "Beta", "Annualized Volatility"
    ],
    "Kotak": [
        "Common Script Name", "Kotak Script Name", "Kotak ISIN",
        "Kotak BSE Code", "52-Week High", "52-Week Low",
        "Avg Daily Volume", "Fyers Last Traded Price", 
        "Fyers P/E Ratio", "Market Sector", "Currency", "Country", "Listing Date",
        "Dividend Yield", "Beta", "Annualized Volatility"
    ],
    "Zerodha": [
        "Common Script Name", "Zerodha Script Name", "Zerodha ISIN",
        "Zerodha BSE Code", "52-Week High", "52-Week Low",
        "Avg Daily Volume", "Fyers Last Traded Price", 
        "Fyers P/E Ratio", "Market Sector", "Currency", "Country", "Listing Date",
        "Dividend Yield", "Beta", "Annualized Volatility"
    ]
}

# Save each broker's data to a separate Excel file
for broker, columns in brokers.items():
    # Check if all required columns exist in the DataFrame
    missing_columns = [col for col in columns if col not in df.columns]
    if missing_columns:
        print(f"Missing columns for {broker}: {missing_columns}")
    else:
        broker_df = df[columns]
        broker_df.to_excel(f'{broker}_pharmaceutical_companies.xlsx', index=False)

print("Excel files for each broker have been created successfully.")
# Out:
# Available columns in the DataFrame:
# ['Common Script Name', 'Fyers Script Name', 'Angel One Script Name', 'ICICI Script Name', 'Kotak Script Name', 'Zerodha Script Name', 'Script Symbol', 'Instrument Type', 'Exchange', 'Fyers ISIN', 'Angel ISIN', 'ICICI ISIN', 'Kotak ISIN', 'Zerodha ISIN', 'Fyers BSE Code', 'Angel BSE Code', 'ICICI BSE Code', 'Kotak BSE Code', 'Zerodha BSE Code', '52-Week High', '52-Week Low', 'Avg Daily Volume', 'Fyers Last Traded Price', 'Angel Last Traded Price', 'Fyers P/E Ratio', 'Angel P/E Ratio', 'Market Sector', 'Currency', 'Country', 'Listing Date', 'Dividend Yield', 'Beta', 'Annualized Volatility']
# Missing columns for Angel: ['Angel Script Name']
# Excel files for each broker have been created successfully.
