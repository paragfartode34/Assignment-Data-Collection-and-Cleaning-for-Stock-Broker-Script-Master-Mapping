# %%
import pandas as pd

# Define the header and data for the CSV file
header = [
    "Common Script Name", "Fyers Script Name", "Angel One Script Name",
    "ICICI Script Name", "Kotak Script Name", "Zerodha Script Name",
    "Script Symbol", "Instrument Type", "Exchange", "Fyers ISIN",
    "Angel ISIN", "ICICI ISIN", "Kotak ISIN", "Zerodha ISIN",
    "Fyers BSE Code", "Angel BSE Code", "ICICI BSE Code",
    "52-Week High", "52-Week Low", "Avg Daily Volume",
    "Fyers Last Traded Price", "Angel Last Traded Price",
    "Fyers P/E Ratio", "Angel P/E Ratio", "Market Sector",
    "Currency", "Country", "Listing Date", "Dividend Yield",
    "Beta", "Annualized Volatility"
]

data = [
    ["Tata Consultancy Services", "TCS001", "TCS-001", "TCS-BS", "TCS-KD", "TCS-ZD",
     "TCS", "Equity", "NSE", "INE567891234", "INE567891234", "INE567891234",
     "INE567891234", "INE567891234", "532540", "532540", "532540", 4000, 3000,
     2000000, 3500, 3520, 25, 24, "IT Services", "INR", "India", "2004-08-19",
     1.50, 1.2, 25],

    ["Infosys", "INF001", "INF-001", "INF-BS", "INF-KD", "INF-ZD",
     "INF", "Equity", "NSE", "INE123456789", "INE123456789", "INE123456789",
     "INE123456789", "INE123456789", "500209", "500209", "500209", 1800, 1300,
     3000000, 1750, 1760, 22, 21, "IT Services", "INR", "India", "1993-06-24",
     1.75, 1.1, 20],

    ["Wipro", "WIP001", "WIP-001", "WIP-BS", "WIP-KD", "WIP-ZD",
     "WIP", "Equity", "NSE", "INE123456790", "INE123456790", "INE123456790",
     "INE123456790", "INE123456790", "507685", "507685", "507685", 800, 600,
     1500000, 750, 755, 18, 17, "IT Services", "INR", "India", "1945-10-14",
     2.00, 1.5, 30],

    ["HCL Technologies", "HCL001", "HCL-001", "HCL-BS", "HCL-KD", "HCL-ZD",
     "HCL", "Equity", "NSE", "INE876543210", "INE876543210", "INE876543210",
     "INE876543210", "INE876543210", "540005", "540005", "540005", 1300, 900,
     1000000, 1250, 1260, 20, 19, "IT Services", "INR", "India", "1999-11-24",
     1.20, 0.9, 15],

    ["Tech Mahindra", "TECH001", "TECH-001", "TECH-BS", "TECH-KD", "TECH-ZD",
     "TECH", "Equity", "NSE", "INE789012345", "INE789012345", "INE789012345",
     "INE789012345", "INE789012345", "532755", "532755", "532755", 1500, 1100,
     800000, 1450, 1460, 21, 20, "IT Services", "INR", "India", "2000-04-15",
     1.80, 1.3, 18],

    ["Mindtree", "MIND001", "MIND-001", "MIND-BS", "MIND-KD", "MIND-ZD",
     "MIND", "Equity", "NSE", "INE234567890", "INE234567890", "INE234567890",
     "INE234567890", "INE234567890", "532819", "532819", "532819", 2200, 1600,
     600000, 2100, 2120, 19, 18, "IT Services", "INR", "India", "1999-01-21",
     1.00, 1.0, 22],

    ["L&T Technology Services", "LTTS001", "LTTS-001", "LTTS-BS", "LTTS-KD", "LTTS-ZD",
     "LTTS", "Equity", "NSE", "INE567890123", "INE567890123", "INE567890123",
     "INE567890123", "INE567890123", "540115", "540115", "540115", 3000, 2000,
     400000, 2900, 2920, 23, 22, "IT Services", "INR", "India", "2016-07-20",
     0.80, 1.4, 15],

    ["Persistent Systems", "PERSIST001", "PERSIST-001", "PERSIST-BS", "PERSIST-KD", "PERSIST-ZD",
     "PERSIST", "Equity", "NSE", "INE456789012", "INE456789012", "INE456789012",
     "INE456789012", "INE456789012", "533328", "533328", "533328", 1500, 1200,
     200000, 1400, 1410, 17, 16, "IT Services", "INR", "India", "2015-06-10",
     0.90, 1.2, 14],

    ["Mphasis", "MPHASIS001", "MPHASIS-001", "MPHASIS-BS", "MPHASIS-KD", "MPHASIS-ZD",
     "MPHASIS", "Equity", "NSE", "INE789456123", "INE789456123", "INE789456123",
     "INE789456123", "INE789456123", "526299", "526299", "526299", 1900, 1400,
     500000, 1800, 1820, 24, 23, "IT Services", "INR", "India", "2001-02-14",
     1.30, 1.1, 20],

    ["Zensar Technologies", "ZENSAR001", "ZENSAR-001", "ZENSAR-BS", "ZENSAR-KD", "ZENSAR-ZD",
     "ZENSAR", "Equity", "NSE", "INE012345678", "INE012345678", "INE012345678",
     "INE012345678", "INE012345678", "504067", "504067", "504067", 1300, 1000,
     300000, 1200, 1210, 15, 14, "IT Services", "INR", "India", "1995-05-09",
     0.70, 0.8, 12],
]

# Create a DataFrame and save it as an Excel file
df = pd.DataFrame(data, columns=header)



excel_file_path
