# %%
import pandas as pd

# Define the data
data = {
    "Common Script Name": [
        "Tata Motors", "Mahindra & Mahindra", "Maruti Suzuki", "Hero MotoCorp",
        "Bajaj Auto", "Ashok Leyland", "TVS Motor Company", "Hyundai Motor India",
        "Honda Motorcycle & Scooter India", "Mercedes-Benz India"
    ],
    "Fyers Script Name": [
        "TATAMOTORS", "M&M", "MARUTI", "HERO", "BAJAJ", "ASHOKLEY",
        "TVS", "HYUNDAI", "HONDA", "MERCEDES"
    ],
    "Angel One Script Name": [
        "TATAMOTORS", "M&M", "MARUTI", "HERO", "BAJAJ", "ASHOKLEY",
        "TVS", "HYUNDAI", "HONDA", "MERCEDES"
    ],
    "ICICI Script Name": [
        "TATAMOTORS", "M&M", "MARUTI", "HERO", "BAJAJ", "ASHOKLEY",
        "TVS", "HYUNDAI", "HONDA", "MERCEDES"
    ],
    "Kotak Script Name": [
        "TATAMOTORS", "M&M", "MARUTI", "HERO", "BAJAJ", "ASHOKLEY",
        "TVS", "HYUNDAI", "HONDA", "MERCEDES"
    ],
    "Zerodha Script Name": [
        "TATAMOTORS", "M&M", "MARUTI", "HERO", "BAJAJ", "ASHOKLEY",
        "TVS", "HYUNDAI", "HONDA", "MERCEDES"
    ],
    "Script Symbol": [
        "TATAMOTORS", "M&M", "MSIL", "HMC", "BAJAJ", "AL", "TVSMOTOR",
        "HMIL", "HMSI", "MBINDIA"
    ],
    "Instrument Type": ["Equity"] * 10,
    "Exchange": ["BSE"] * 10,
    "Fyers ISIN": [
        "INE155A01022", "INE101A01026", "INE585B01010", "INE158A01026",
        "INE477A01014", "INE208A01029", "INE494A01016", "INE274A01028",
        "INE202A01027", "INE208B01015"
    ],
    "Angel ISIN": [
        "INE155A01022", "INE101A01026", "INE585B01010", "INE158A01026",
        "INE477A01014", "INE208A01029", "INE494A01016", "INE274A01028",
        "INE202A01027", "INE208B01015"
    ],
    "ICICI ISIN": [
        "INE155A01022", "INE101A01026", "INE585B01010", "INE158A01026",
        "INE477A01014", "INE208A01029", "INE494A01016", "INE274A01028",
        "INE202A01027", "INE208B01015"
    ],
    "Kotak ISIN": [
        "INE155A01022", "INE101A01026", "INE585B01010", "INE158A01026",
        "INE477A01014", "INE208A01029", "INE494A01016", "INE274A01028",
        "INE202A01027", "INE208B01015"
    ],
    "Zerodha ISIN": [
        "INE155A01022", "INE101A01026", "INE585B01010", "INE158A01026",
        "INE477A01014", "INE208A01029", "INE494A01016", "INE274A01028",
        "INE202A01027", "INE208B01015"
    ],
    "Fyers BSE Code": [
        "500570", "500520", "532500", "500182", "532977", "500477",
        "532343", "541540", "530999", "500200"
    ],
    "Angel BSE Code": [
        "500570", "500520", "532500", "500182", "532977", "500477",
        "532343", "541540", "530999", "500200"
    ],
    "ICICI BSE Code": [
        "500570", "500520", "532500", "500182", "532977", "500477",
        "532343", "541540", "530999", "500200"
    ],
    "52-Week High": [
        550, 1200, 10000, 3000, 4000, 2000, 1300, 1600, 3500, 8000
    ],
    "52-Week Low": [
        400, 850, 7000, 2500, 3200, 1500, 1000, 1200, 2800, 6500
    ],
    "Avg Daily Volume": [
        1200000, 900000, 1000000, 600000, 500000, 400000, 300000,
        250000, 350000, 150000
    ],
    "Fyers Last Traded Price": [
        500, 1100, 9800, 2900, 3900, 1900, 1250, 1550, 3300, 7500
    ],
    "Angel Last Traded Price": [
        502, 1105, 9750, 2850, 3850, 1880, 1240, 1540, 3250, 7600
    ],
    "Market Sector": [
        "Automotive", "Automotive", "Automotive", "Automotive",
        "Automotive", "Automotive", "Automotive", "Automotive",
        "Automotive", "Automotive"
    ],
    "Currency": ["INR"] * 10,
    "Country": ["India"] * 10,
    "Listing Date": [
        "1998-01-01", "1998-01-01", "2003-01-01", "2001-01-01",
        "2005-01-01", "2003-01-01", "2006-01-01", "1997-01-01",
        "2005-01-01", "2015-01-01"
    ],
    "Dividend Yield": [
        "1.2%", "1.5%", "0.8%", "1.0%", "2.5%", "1.8%", "1.2%",
        "1.3%", "1.1%", "0.6%"
    ],
    "Beta": [
        1.1, 1.3, 1.4, 1.2, 0.9, 1.0, 1.1, 1.0, 0.8, 1.5
    ],
    "Annualized Volatility": [
        "20%", "15%", "18%", "12%", "14%", "16%", "13%", "15%",
        "17%", "10%"
    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Define broker-specific columns, omitting columns that don't exist
brokers = {
    "Fyers": ["Common Script Name", "Fyers Script Name", "Fyers ISIN", "Fyers BSE Code", "Fyers Last Traded Price"],
    "Angel": ["Common Script Name", "Angel One Script Name", "Angel ISIN", "Angel BSE Code", "Angel Last Traded Price"],
    "ICICI": ["Common Script Name", "ICICI Script Name", "ICICI ISIN", "ICICI BSE Code"],
    "Kotak": ["Common Script Name", "Kotak Script Name", "Kotak ISIN"],
    "Zerodha": ["Common Script Name", "Zerodha Script Name", "Zerodha ISIN"]
}

# Save each broker's data to a separate Excel file
for broker, columns in brokers.items():
    available_columns = [col for col in columns if col in df.columns]
    broker_df = df[available_columns]
    broker_df.to_excel(f'{broker}_automotive_data.xlsx', index=False)
    print(f"{broker} data saved successfully.")
# Out:
# Fyers data saved successfully.
# Angel data saved successfully.
# ICICI data saved successfully.
# Kotak data saved successfully.
# Zerodha data saved successfully.

# %%
import pandas as pd

# Data for Automobiles Company
data = {
    "Common Script Name": [
        "Tata Motors", "Mahindra & Mahindra", "Maruti Suzuki", "Hero MotoCorp",
        "Bajaj Auto", "Ashok Leyland", "TVS Motor Company", "Hyundai Motor India",
        "Honda Motorcycle & Scooter India", "Mercedes-Benz India"
    ],
    "Fyers Script Name": [
        "TATAMOTORS", "M&M", "MARUTI", "HERO", "BAJAJ", "ASHOKLEY",
        "TVS", "HYUNDAI", "HONDA", "MERCEDES"
    ],
    "Angel One Script Name": [
        "TATAMOTORS", "M&M", "MARUTI", "HERO", "BAJAJ", "ASHOKLEY",
        "TVS", "HYUNDAI", "HONDA", "MERCEDES"
    ],
    "ICICI Script Name": [
        "TATAMOTORS", "M&M", "MARUTI", "HERO", "BAJAJ", "ASHOKLEY",
        "TVS", "HYUNDAI", "HONDA", "MERCEDES"
    ],
    "Kotak Script Name": [
        "TATAMOTORS", "M&M", "MARUTI", "HERO", "BAJAJ", "ASHOKLEY",
        "TVS", "HYUNDAI", "HONDA", "MERCEDES"
    ],
    "Zerodha Script Name": [
        "TATAMOTORS", "M&M", "MARUTI", "HERO", "BAJAJ", "ASHOKLEY",
        "TVS", "HYUNDAI", "HONDA", "MERCEDES"
    ],
    "Script Symbol": [
        "TATAMOTORS", "M&M", "MSIL", "HMC", "BAJAJ", "AL", "TVSMOTOR",
        "HMIL", "HMSI", "MBINDIA"
    ],
    "Instrument Type": ["Equity"] * 10,
    "Exchange": ["BSE"] * 10,
    "Fyers ISIN": [
        "INE155A01022", "INE101A01026", "INE585B01010", "INE158A01026",
        "INE477A01014", "INE208A01029", "INE494A01016", "INE274A01028",
        "INE202A01027", "INE208B01015"
    ],
    "Angel ISIN": [
        "INE155A01022", "INE101A01026", "INE585B01010", "INE158A01026",
        "INE477A01014", "INE208A01029", "INE494A01016", "INE274A01028",
        "INE202A01027", "INE208B01015"
    ],
    "ICICI ISIN": [
        "INE155A01022", "INE101A01026", "INE585B01010", "INE158A01026",
        "INE477A01014", "INE208A01029", "INE494A01016", "INE274A01028",
        "INE202A01027", "INE208B01015"
    ],
    "Kotak ISIN": [
        "INE155A01022", "INE101A01026", "INE585B01010", "INE158A01026",
        "INE477A01014", "INE208A01029", "INE494A01016", "INE274A01028",
        "INE202A01027", "INE208B01015"
    ],
    "Zerodha ISIN": [
        "INE155A01022", "INE101A01026", "INE585B01010", "INE158A01026",
        "INE477A01014", "INE208A01029", "INE494A01016", "INE274A01028",
        "INE202A01027", "INE208B01015"
    ],
    "Fyers BSE Code": [
        "500570", "500520", "532500", "500182", "532977", "500477",
        "532343", "541540", "530999", "500200"
    ],
    "Angel BSE Code": [
        "500570", "500520", "532500", "500182", "532977", "500477",
        "532343", "541540", "530999", "500200"
    ],
    "ICICI BSE Code": [
        "500570", "500520", "532500", "500182", "532977", "500477",
        "532343", "541540", "530999", "500200"
    ],
    "52-Week High": [
        550, 1200, 10000, 3000, 4000, 2000, 1300, 1600, 3500, 8000
    ],
    "52-Week Low": [
        400, 850, 7000, 2500, 3200, 1500, 1000, 1200, 2800, 6500
    ],
    "Avg Daily Volume": [
        1200000, 900000, 1000000, 600000, 500000, 400000, 300000,
        250000, 350000, 150000
    ],
    "Fyers Last Traded Price": [
        500, 1100, 9800, 2900, 3900, 1900, 1250, 1550, 3300, 7500
    ],
    "Angel Last Traded Price": [
        502, 1105, 9750, 2850, 3850, 1880, 1240, 1540, 3250, 7600
    ],
    "Fyers P/E Ratio": [
        25, 18, 30, 20, 15, 22, 19, 25, 21, 27
    ],
    "Angel P/E Ratio": [
        24, 19, 29, 21, 16, 21, 18, 24, 20, 26
    ],
    "Market Sector": [
        "Automotive", "Automotive", "Automotive", "Automotive",
        "Automotive", "Automotive", "Automotive", "Automotive",
        "Automotive", "Automotive"
    ],
    "Currency": ["INR"] * 10,
    "Country": ["India"] * 10,
    "Listing Date": [
        "1998-01-01", "1998-01-01", "2003-01-01", "2001-01-01",
        "2005-01-01", "2003-01-01", "2006-01-01", "1997-01-01",
        "2005-01-01", "2015-01-01"
    ],
    "Dividend Yield": [
        "1.2%", "1.5%", "0.8%", "1.0%", "2.5%", "1.8%", "1.2%",
        "1.3%", "1.1%", "0.6%"
    ],
    "Beta": [
        1.1, 1.3, 1.4, 1.2, 0.9, 1.0, 1.1, 1.0, 0.8, 1.5
    ],
    "Annualized Volatility": [
        "20%", "15%", "18%", "12%", "14%", "16%", "13%", "15%",
        "17%", "10%"
    ]
}


df = pd.DataFrame(data)

# Save the DataFrame to an Excel file
df.to_excel('automotive_companies_data.xlsx', index=False)
