# %%
import pandas as pd

# Data for oil and gas
data = {
    "Common Script Name": [
        "Reliance Industries", 
        "Indian Oil Corporation", 
        "Bharat Petroleum Corporation Limited", 
        "Hindustan Petroleum Corporation Limited", 
        "Oil and Natural Gas Corporation"
    ],
    "Fyers Script Name": [
        "RELIANCEIND", 
        "IOC", 
        "BPCL", 
        "HPCL", 
        "ONGC"
    ],
    "Angel One Script Name": [
        "RELIANCE", 
        "INDIAN OIL", 
        "BPCL", 
        "HPCL", 
        "ONGC"
    ],
    "ICICI Script Name": [
        "RELIANCE", 
        "IOC", 
        "BPCL", 
        "HPCL", 
        "ONGC"
    ],
    "Kotak Script Name": [
        "RELIANCE", 
        "IOC", 
        "BPCL", 
        "HPCL", 
        "ONGC"
    ],
    "Zerodha Script Name": [
        "RELIANCE", 
        "IOC", 
        "BPCL", 
        "HPCL", 
        "ONGC"
    ],
    "Script Symbol": [
        "RIL", 
        "IOC", 
        "BPCL", 
        "HPCL", 
        "ONGC"
    ],
    "Instrument Type": [
        "Equity", 
        "Equity", 
        "Equity", 
        "Equity", 
        "Equity"
    ],
    "Exchange": [
        "NSE", 
        "NSE", 
        "NSE", 
        "NSE", 
        "NSE"
    ],
    "Fyers ISIN": [
        "INE002A01018", 
        "INE242A01010", 
        "INE129A01019", 
        "INE094A01015", 
        "INE213A01029"
    ],
    "Angel ISIN": [
        "INE002A01018", 
        "INE242A01010", 
        "INE129A01019", 
        "INE094A01015", 
        "INE213A01029"
    ],
    "ICICI ISIN": [
        "INE002A01018", 
        "INE242A01010", 
        "INE129A01019", 
        "INE094A01015", 
        "INE213A01029"
    ],
    "Kotak ISIN": [
        "INE002A01018", 
        "INE242A01010", 
        "INE129A01019", 
        "INE094A01015", 
        "INE213A01029"
    ],
    "Zerodha ISIN": [
        "INE002A01018", 
        "INE242A01010", 
        "INE129A01019", 
        "INE094A01015", 
        "INE213A01029"
    ],
    "Fyers BSE Code": [
        "500325", 
        "530965", 
        "500547", 
        "500104", 
        "500312"
    ],
    "Angel BSE Code": [
        "500325", 
        "530965", 
        "500547", 
        "500104", 
        "500312"
    ],
    "ICICI BSE Code": [
        "500325", 
        "530965", 
        "500547", 
        "500104", 
        "500312"
    ],
    "52-Week High": [
        2800, 
        150, 
        500, 
        350, 
        200
    ],
    "52-Week Low": [
        2100, 
        90, 
        350, 
        270, 
        120
    ],
    "Avg Daily Volume": [
        10000000, 
        8000000, 
        5000000, 
        6000000, 
        9000000
    ],
    "Fyers Last Traded Price": [
        2700, 
        140, 
        490, 
        330, 
        180
    ],
    "Angel Last Traded Price": [
        2705, 
        141, 
        492, 
        332, 
        181
    ],
    "Fyers P/E Ratio": [
        30.00, 
        15.00, 
        20.00, 
        18.00, 
        14.00
    ],
    "Angel P/E Ratio": [
        29.50, 
        14.50, 
        19.50, 
        17.50, 
        13.50
    ],
    "Market Sector": [
        "Oil and Gas", 
        "Oil and Gas", 
        "Oil and Gas", 
        "Oil and Gas", 
        "Oil and Gas"
    ],
    "Currency": [
        "INR", 
        "INR", 
        "INR", 
        "INR", 
        "INR"
    ],
    "Country": [
        "India", 
        "India", 
        "India", 
        "India", 
        "India"
    ],
    "Listing Date": [
        "1977-05-27", 
        "2002-01-01", 
        "2001-04-12", 
        "2000-01-10", 
        "1991-10-01"
    ],
    "Dividend Yield": [
        0.50, 
        1.00, 
        0.75, 
        0.80, 
        1.20
    ],
    "Beta": [
        1.2, 
        0.8, 
        1.0, 
        1.1, 
        1.3
    ],
    "Annualized Volatility": [
        "25%", 
        "20%", 
        "15%", 
        "18%", 
        "22%"
    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Save the DataFrame to an Excel file
df.to_excel('Oil_and_Gas_companies_mapping.xlsx', index=False)
