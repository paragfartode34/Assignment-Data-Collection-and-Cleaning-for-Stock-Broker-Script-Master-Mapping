# %%
import pandas as pd

# Data Miscellaneous company
data = {
    "Common Script Name": [
        "Mahindra & Mahindra Financial Services",
        "Larsen & Toubro (L&T)",
        "Adani Ports and Special Economic Zone",
        "Tata Power",
        "NTPC Limited",
        "GAIL (India) Limited",
        "Indian Hotels Company Limited (IHCL)",
        "Infosys BPM",
        "Zee Entertainment Enterprises",
        "Sun TV Network"
    ],
    "Fyers Script Name": [
        "M&M Finance", "L&T", "Adani Ports", "Tata Power", "NTPC", 
        "GAIL", "IHCL", "Infosys BPM", "ZEE", "Sun TV"
    ],
    "Angel One Script Name": [
        "M&M Finance", "L&T", "Adani Ports", "Tata Power", "NTPC", 
        "GAIL", "IHCL", "Infosys BPM", "ZEE", "Sun TV"
    ],
    "ICICI Script Name": [
        "M&M Finance", "L&T", "Adani Ports", "Tata Power", "NTPC", 
        "GAIL", "IHCL", "Infosys BPM", "ZEE", "Sun TV"
    ],
    "Kotak Script Name": [
        "M&M Finance", "L&T", "Adani Ports", "Tata Power", "NTPC", 
        "GAIL", "IHCL", "Infosys BPM", "ZEE", "Sun TV"
    ],
    "Zerodha Script Name": [
        "M&M Finance", "L&T", "Adani Ports", "Tata Power", "NTPC", 
        "GAIL", "IHCL", "Infosys BPM", "ZEE", "Sun TV"
    ],
    "Script Symbol": [
        "M&M", "LT", "ADANIPORTS", "TATAPOWER", "NTPC", 
        "GAIL", "IHCL", "INFBPM", "ZEE", "SUNTV"
    ],
    "Instrument Type": [
        "Equity", "Equity", "Equity", "Equity", "Equity", 
        "Equity", "Equity", "Equity", "Equity", "Equity"
    ],
    "Exchange": ["BSE"] * 10,
    "Fyers ISIN": [
        "INE101A01026", "INE018A01030", "INE742F01042", "INE245A01021", 
        "INE733E01010", "INE368E01012", "INE053A01029", "INE100I01024", 
        "INE256A01026", "INE424A01018"
    ],
    "Angel ISIN": [
        "INE101A01026", "INE018A01030", "INE742F01042", "INE245A01021", 
        "INE733E01010", "INE368E01012", "INE053A01029", "INE100I01024", 
        "INE256A01026", "INE424A01018"
    ],
    "ICICI ISIN": [
        "INE101A01026", "INE018A01030", "INE742F01042", "INE245A01021", 
        "INE733E01010", "INE368E01012", "INE053A01029", "INE100I01024", 
        "INE256A01026", "INE424A01018"
    ],
    "Kotak ISIN": [
        "INE101A01026", "INE018A01030", "INE742F01042", "INE245A01021", 
        "INE733E01010", "INE368E01012", "INE053A01029", "INE100I01024", 
        "INE256A01026", "INE424A01018"
    ],
    "Zerodha ISIN": [
        "INE101A01026", "INE018A01030", "INE742F01042", "INE245A01021", 
        "INE733E01010", "INE368E01012", "INE053A01029", "INE100I01024", 
        "INE256A01026", "INE424A01018"
    ],
    "Fyers BSE Code": [
        "500271", "500510", "532921", "500400", "532555", 
        "532155", "500840", "530754", "505537", "532733"
    ],
    "Angel BSE Code": [
        "500271", "500510", "532921", "500400", "532555", 
        "532155", "500840", "530754", "505537", "532733"
    ],
    "ICICI BSE Code": [
        "500271", "500510", "532921", "500400", "532555", 
        "532155", "500840", "530754", "505537", "532733"
    ],
    "52-Week High": [
        885.00, 2000.00, 950.00, 280.00, 195.00, 
        145.00, 380.00, 1800.00, 400.00, 600.00
    ],
    "52-Week Low": [
        560.00, 1500.00, 650.00, 210.00, 140.00, 
        100.00, 280.00, 1200.00, 250.00, 400.00
    ],
    "Avg Daily Volume": [
        1500000, 2000000, 5000000, 3000000, 4500000, 
        1000000, 800000, 2500000, 1800000, 1200000
    ],
    "Fyers Last Traded Price": [
        860.00, 1950.00, 920.00, 265.00, 190.00, 
        140.00, 370.00, 1700.00, 380.00, 590.00
    ],
    "Angel Last Traded Price": [
        861.00, 1952.00, 922.00, 266.00, 191.00, 
        141.00, 371.00, 1702.00, 381.00, 591.00
    ],
    "Fyers P/E Ratio": [
        16.50, 28.00, 35.00, 20.00, 12.00, 
        16.00, 45.00, 28.00, 20.00, 18.00
    ],
    "Angel P/E Ratio": [
        16.60, 28.50, 36.00, 20.50, 12.50, 
        16.20, 45.50, 28.20, 20.10, 18.10
    ],
    "Market Sector": [
        "Financial Services", "Engineering", "Infrastructure", "Utilities", 
        "Utilities", "Energy", "Hospitality", "IT Services", 
        "Media", "Media"
    ],
    "Currency": ["INR"] * 10,
    "Country": ["India"] * 10,
    "Listing Date": [
        "1994-06-23", "1994-01-05", "2006-05-09", "2005-06-02", 
        "2004-10-01", "2002-03-26", "2000-02-16", "2005-08-22", 
        "1994-03-10", "2004-12-07"
    ],
    "Dividend Yield": [
        2.00, 1.50, 0.80, 2.50, 3.00, 
        4.00, 1.20, 1.50, 0.90, 1.00
    ],
    "Beta": [
        0.95, 1.10, 1.05, 0.85, 0.90, 
        0.88, 1.00, 1.20, 1.05, 1.00
    ],
    "Annualized Volatility": [
        20.00, 18.00, 25.00, 22.00, 15.00, 
        18.00, 12.00, 15.00, 14.00, 13.00
    ]
}

# Create DataFrame
df = pd.DataFrame(data)
