# %%
import pandas as pd

# Data for the Food and Beverage companies
data = {
    "Common Script Name": [
        "Britannia Industries", "Coca-Cola India", "PepsiCo India", "Parle Agro", "ITC Foods"
    ],
    "Fyers Script Name": [
        "Fyers_Britannia", "Fyers_CocaCola", "Fyers_Pepsi", "Fyers_ParleAgro", "Fyers_ITC"
    ],
    "Angel One Script Name": [
        "Angel_Britannia", "Angel_CocaCola", "Angel_Pepsi", "Angel_ParleAgro", "Angel_ITC"
    ],
    "ICICI Script Name": [
        "ICICI_Britannia", "ICICI_CocaCola", "ICICI_Pepsi", "ICICI_ParleAgro", "ICICI_ITC"
    ],
    "Kotak Script Name": [
        "Kotak_Britannia", "Kotak_CocaCola", "Kotak_Pepsi", "Kotak_ParleAgro", "Kotak_ITC"
    ],
    "Zerodha Script Name": [
        "Zerodha_Britannia", "Zerodha_CocaCola", "Zerodha_Pepsi", "Zerodha_ParleAgro", "Zerodha_ITC"
    ],
    "Script Symbol": [
        "BRITANNIA", "COCA-COLA", "PEPSICO", "PARLEAGRO", "ITC"
    ],
    "Instrument Type": [
        "Equity", "Equity", "Equity", "Equity", "Equity"
    ],
    "Exchange": [
        "BSE", "BSE", "BSE", "BSE", "BSE"
    ],
    "Fyers ISIN": [
        "INE488A01016", "INE154A01026", "INE244A01024", "INE133B01028", "INE154A01010"
    ],
    "Angel ISIN": [
        "INE488A01016", "INE154A01026", "INE244A01024", "INE133B01028", "INE154A01010"
    ],
    "ICICI ISIN": [
        "INE488A01016", "INE154A01026", "INE244A01024", "INE133B01028", "INE154A01010"
    ],
    "Kotak ISIN": [
        "INE488A01016", "INE154A01026", "INE244A01024", "INE133B01028", "INE154A01010"
    ],
    "Zerodha ISIN": [
        "INE488A01016", "INE154A01026", "INE244A01024", "INE133B01028", "INE154A01010"
    ],
    "Fyers BSE Code": [
        "500068", "500186", "500330", "500123", "500875"
    ],
    "Angel BSE Code": [
        "500068", "500186", "500330", "500123", "500875"
    ],
    "ICICI BSE Code": [
        "500068", "500186", "500330", "500123", "500875"
    ],
    "52-Week High": [
        4000, 5000, 4500, 3000, 3000
    ],
    "52-Week Low": [
        3000, 3500, 3200, 2500, 2400
    ],
    "Avg Daily Volume": [
        100000, 200000, 150000, 80000, 120000
    ],
    "Fyers Last Traded Price": [
        3800, 4800, 4300, 2800, 2700
    ],
    "Angel Last Traded Price": [
        3800, 4800, 4300, 2800, 2700
    ],
    "Fyers P/E Ratio": [
        35, 30, 28, 24, 22
    ],
    "Angel P/E Ratio": [
        36, 31, 29, 25, 23
    ],
    "Market Sector": [
        "Food & Beverage", "Food & Beverage", "Food & Beverage", "Food & Beverage", "Food & Beverage"
    ],
    "Currency": [
        "INR", "INR", "INR", "INR", "INR"
    ],
    "Country": [
        "India", "India", "India", "India", "India"
    ],
    "Listing Date": [
        "1998-12-23", "1993-05-20", "1994-03-10", "1992-07-15", "1996-01-01"
    ],
    "Dividend Yield": [
        "1.5%", "2.0%", "1.8%", "1.2%", "1.0%"
    ],
    "Beta": [
        0.9, 0.85, 0.95, 0.75, 0.80
    ],
    "Annualized Volatility": [
        "15%", "12%", "10%", "8%", "9%"
    ]
}

# Creating a DataFrame
df = pd.DataFrame(data)

# Saving to Excel
df.to_excel('Food_and_be_companies_mapping.xlsx', index=False) 

excel_file_path
